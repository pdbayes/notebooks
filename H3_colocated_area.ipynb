# %%
import pandas as pd
import h3
import shapely
import geopandas as gpd
import numpy as np

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Read the CSV file into a Pandas DataFrame
file_path = 'loit.csv'  
df = pd.read_csv(file_path, encoding = 'utf-8')

# Define a list of column names to select
selected_column_names = ['start', 'end','name', 'region', 'flag', 'lat', 'lon']

# Select the specified columns from the DataFrame
df = df[selected_column_names]

# Define a dictionary to map the old column names to the new names
column_name_mapping = {
    'name': 'Name',
    'region': 'Regions',
    'flag': 'Country',
    'lat': 'Latitude',
    'lon': 'Longitude',
    'start':'Start',
    'end': 'End'
}

# Use the rename method to rename the columns
df.rename(columns=column_name_mapping, inplace=True)
df['Start']=pd.to_datetime(df['Start'], format='ISO8601')
df['End']=pd.to_datetime(df['End'], format='ISO8601')
df['hour'] = df.apply(lambda row: pd.date_range(row['Start'], row['End'], freq='H'), axis=1)
df = df.explode('hour').reset_index() 
# Display the first few rows of the DataFrame
df.head()
# Out:
#    index                            Start                       End      Name  \
# 0      0 2022-10-06 07:58:16.760000+00:00 2024-03-25 23:57:42+00:00   'LS361'
# 1      0 2022-10-06 07:58:16.760000+00:00 2024-03-25 23:57:42+00:00   'LS361'
# 2      0 2022-10-06 07:58:16.760000+00:00 2024-03-25 23:57:42+00:00   'LS361'
# 3      0 2022-10-06 07:58:16.760000+00:00 2024-03-25 23:57:42+00:00   'LS361'
# 4      0 2022-10-06 07:58:16.760000+00:00 2024-03-25 23:57:42+00:00   'LS361'
#
#                                              Regions Country  Latitude  \
# 0  {'mpa': [], 'eez': ['8486'], 'rfmo': ['APFIC',...   'CHN'   27.1495
# 1  {'mpa': [], 'eez': ['8486'], 'rfmo': ['APFIC',...   'CHN'   27.1495
# 2  {'mpa': [], 'eez': ['8486'], 'rfmo': ['APFIC',...   'CHN'   27.1495
# 3  {'mpa': [], 'eez': ['8486'], 'rfmo': ['APFIC',...   'CHN'   27.1495
# 4  {'mpa': [], 'eez': ['8486'], 'rfmo': ['APFIC',...   'CHN'   27.1495
#
#    Longitude                             hour
# 0   121.9008 2022-10-06 07:58:16.760000+00:00
# 1   121.9008 2022-10-06 08:58:16.760000+00:00
# 2   121.9008 2022-10-06 09:58:16.760000+00:00
# 3   121.9008 2022-10-06 10:58:16.760000+00:00
# 4   121.9008 2022-10-06 11:58:16.760000+00:00

# %%
def get_hexagon_grid(latitude, longitude, resolution):
    """
    Generate a hexagonal grid GeoDataFrame centered around a specified location.
    Parameters:
    - latitude (float): Latitude of the center point.
    - longitude (float): Longitude of the center point.
    - resolution (int): H3 resolution for hexagons.
    - ring_size (int): Number of rings to create around the center hexagon.
    Returns:
    - hexagon_df (geopandas.GeoDataFrame): GeoDataFrame containing hexagons and their geometries.
    """

    # Get the H3 hexagons covering the specified location
    hexagons= []
    for i, row in df.iterrows():
        hexagons.append(h3.geo_to_h3(row.Latitude, row.Longitude, resolution))  # Convert the set to a list

    # Create a GeoDataFrame with hexagons and their corresponding geometries
    hexagon_geometries = [shapely.geometry.Polygon(h3.h3_to_geo_boundary(hexagon, geo_json=True)) for hexagon in hexagons]
    hexagon_df = gpd.GeoDataFrame({'Hexagon_ID': hexagons, 'geometry': hexagon_geometries})
    df['Hexagon_ID']=hexagons
    return hexagon_df

# %%
df
# Out:
#         index                            Start                       End  \
# 0           0 2022-10-06 07:58:16.760000+00:00 2024-03-25 23:57:42+00:00
# 1           0 2022-10-06 07:58:16.760000+00:00 2024-03-25 23:57:42+00:00
# 2           0 2022-10-06 07:58:16.760000+00:00 2024-03-25 23:57:42+00:00
# 3           0 2022-10-06 07:58:16.760000+00:00 2024-03-25 23:57:42+00:00
# 4           0 2022-10-06 07:58:16.760000+00:00 2024-03-25 23:57:42+00:00
# ...       ...                              ...                       ...
# 141579   9999        2024-01-12 19:35:00+00:00 2024-01-13 20:09:53+00:00
# 141580   9999        2024-01-12 19:35:00+00:00 2024-01-13 20:09:53+00:00
# 141581   9999        2024-01-12 19:35:00+00:00 2024-01-13 20:09:53+00:00
# 141582   9999        2024-01-12 19:35:00+00:00 2024-01-13 20:09:53+00:00
# 141583   9999        2024-01-12 19:35:00+00:00 2024-01-13 20:09:53+00:00
#
#                      Name                                            Regions  \
# 0                 'LS361'  {'mpa': [], 'eez': ['8486'], 'rfmo': ['APFIC',...
# 1                 'LS361'  {'mpa': [], 'eez': ['8486'], 'rfmo': ['APFIC',...
# 2                 'LS361'  {'mpa': [], 'eez': ['8486'], 'rfmo': ['APFIC',...
# 3                 'LS361'  {'mpa': [], 'eez': ['8486'], 'rfmo': ['APFIC',...
# 4                 'LS361'  {'mpa': [], 'eez': ['8486'], 'rfmo': ['APFIC',...
# ...                   ...                                                ...
# 141579   'ZHELINGYU69361'  {'mpa': [], 'eez': ['8486'], 'rfmo': ['IWC', '...
# 141580   'ZHELINGYU69361'  {'mpa': [], 'eez': ['8486'], 'rfmo': ['IWC', '...
# 141581   'ZHELINGYU69361'  {'mpa': [], 'eez': ['8486'], 'rfmo': ['IWC', '...
# 141582   'ZHELINGYU69361'  {'mpa': [], 'eez': ['8486'], 'rfmo': ['IWC', '...
# 141583   'ZHELINGYU69361'  {'mpa': [], 'eez': ['8486'], 'rfmo': ['IWC', '...
#
#        Country  Latitude  Longitude                             hour
# 0        'CHN'   27.1495   121.9008 2022-10-06 07:58:16.760000+00:00
# 1        'CHN'   27.1495   121.9008 2022-10-06 08:58:16.760000+00:00
# 2        'CHN'   27.1495   121.9008 2022-10-06 09:58:16.760000+00:00
# 3        'CHN'   27.1495   121.9008 2022-10-06 10:58:16.760000+00:00
# 4        'CHN'   27.1495   121.9008 2022-10-06 11:58:16.760000+00:00
# ...        ...       ...        ...                              ...
# 141579   'CHN'   27.8944   121.9663        2024-01-13 15:35:00+00:00
# 141580   'CHN'   27.8944   121.9663        2024-01-13 16:35:00+00:00
# 141581   'CHN'   27.8944   121.9663        2024-01-13 17:35:00+00:00
# 141582   'CHN'   27.8944   121.9663        2024-01-13 18:35:00+00:00
# 141583   'CHN'   27.8944   121.9663        2024-01-13 19:35:00+00:00
#
# [141584 rows x 9 columns]

# %%
lat = 24.7
lng = 120.3

# Generate H3 hexagons at a specified resolution (e.g., 9)
resolution = 5



# Hexagon shapes for vessels
hexagon_df = get_hexagon_grid(lat, lng, resolution)

# Visualize the first rows of the GeoDataFrame
hexagon_df.head()
# Out:
#         Hexagon_ID                                           geometry
# 0  854b144bfffffff  POLYGON ((121.80966 27.13923, 121.82689 27.062...
# 1  854b144bfffffff  POLYGON ((121.80966 27.13923, 121.82689 27.062...
# 2  854b144bfffffff  POLYGON ((121.80966 27.13923, 121.82689 27.062...
# 3  854b144bfffffff  POLYGON ((121.80966 27.13923, 121.82689 27.062...
# 4  854b144bfffffff  POLYGON ((121.80966 27.13923, 121.82689 27.062...

# %%
grouped_df = df.groupby('hour').count('Hexagon_ID')
#grouped_df = grouped_df.groupby.agg({'Name': ['count', '<br>'.join]}).reset_index()
# Rename columns for clarity
#grouped_df.columns = ['Hexagon_ID', 'hour', 'Count', 'Vessels']
#grouped_df.replace("''", np.nan,regex=True, inplace=True)
# Visualize the first rows of the DataFrame
#grouped_df=grouped_df.dropna()
grouped_df.head(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 grouped_df = df.groupby('hour').count('Hexagon_ID')
#       2 #grouped_df = grouped_df.groupby.agg({'Name': ['count', '<br>'.join]}).reset_index()
#       3 # Rename columns for clarity
#       4 #grouped_df.columns = ['Hexagon_ID', 'hour', 'Count', 'Vessels']
#       5 #grouped_df.replace("''", np.nan,regex=True, inplace=True)
#       6 # Visualize the first rows of the DataFrame
#       7 #grouped_df=grouped_df.dropna()
#       8 grouped_df.head(50)
#
# TypeError: count() takes 1 positional argument but 2 were given

# %%
import plotly.express as px
def create_choropleth_map(geojson_df, data_df, alpha=0.4, map_style="carto-positron", color_scale="Viridis"):
    """
    Create an interactive choropleth map using Plotly Express.
    Parameters:
    - geojson_df (GeoDataFrame): GeoJSON data containing polygon geometries.
    - data_df (DataFrame): DataFrame containing data to be visualized on the map.
    - alpha (float): Opacity level for the map polygons (0.0 to 1.0).
    - map_style (str): Map style for the Plotly map (e.g., "carto-positron").
    - color_scale (str): Color scale for the choropleth map.
    Returns:
    None
    """
    # Merge the GeoJSON data with your DataFrame
    merged_df = geojson_df.merge(data_df, on="Hexagon_ID", how="left")

    # Create a choropleth map using px.choropleth_mapbox
    fig = px.choropleth_mapbox(
        merged_df,
        geojson=merged_df.geometry,
        locations=merged_df.index,  # Use index as locations to avoid duplicate rows
        color="Count",
        color_continuous_scale=color_scale,
        title="Vessel Distribution Around Taiwan",
        mapbox_style=map_style,
        animation_frame='hour',
        center={"lat": lat, "lon": lng},  # Adjust the center as needed
        zoom=5,
    )

    # Customize the opacity of the hexagons
    fig.update_traces(marker=dict(opacity=alpha))

    # Add hover data for hotel names
    fig.update_traces(customdata=merged_df["Vessels"])

    # Define the hover template 
    hover_template = "<b>Vessels:</b> %{customdata}<extra></extra>"
    fig.update_traces(hovertemplate=hover_template)

    # Set margins to 25 on all sides
    fig.update_layout(margin=dict(l=35, r=35, t=45, b=35))
    
    # Adjust the width of the visualization
    fig.update_layout(width=1000) 

    fig.show()

# Call the function with your GeoJSON and DataFrame
create_choropleth_map(geojson_df=hexagon_df, data_df=grouped_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[8], line 50
#      49 # Call the function with your GeoJSON and DataFrame
# ---> 50 create_choropleth_map(geojson_df=hexagon_df, data_df=grouped_df)
#
# Cell In[8], line 18, in create_choropleth_map(geojson_df, data_df, alpha, map_style, color_scale)
#      17 # Create a choropleth map using px.choropleth_mapbox
# ---> 18 fig = px.choropleth_mapbox(
#      19     merged_df,
#      20     geojson=merged_df.geometry,
#      21     locations=merged_df.index,  # Use index as locations to avoid duplicate rows
#      22     color="Count",
#      23     color_continuous_scale=color_scale,
#      24     title="Vessel Distribution Around Taiwan",
#      25     mapbox_style=map_style,
#      26     animation_frame='hour',
#      27     center={"lat": lat, "lon": lng},  # Adjust the center as needed
#      28     zoom=5,
#      29 )
#      31 # Customize the opacity of the hexagons
#
# File /opt/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py:1284, in choropleth_mapbox(data_frame, geojson, featureidkey, locations, color, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, zoom, center, mapbox_style, title, template, width, height)
#    1280 """
#    1281 In a Mapbox choropleth map, each row of `data_frame` is represented by a
#    1282 colored region on a Mapbox map.
#    1283 """
# -> 1284 return make_figure(args=locals(), constructor=go.Choroplethmapbox)
#
# File /opt/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py:2099, in make_figure(args, constructor, trace_patch, layout_patch)
#    2097     args = process_dataframe_timeline(args)
# -> 2099 trace_specs, grouped_mappings, sizeref, show_colorbar = infer_config(
#    2100     args, constructor, trace_patch, layout_patch
#    2101 )
#    2102 grouper = [x.grouper or one_group for x in grouped_mappings] or [one_group]
#
# File /opt/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py:1955, in infer_config(args, constructor, trace_patch, layout_patch)
#    1952     trace_patch["featureidkey"] = args["featureidkey"]
#    1953     trace_patch["geojson"] = (
#    1954         args["geojson"]
# -> 1955         if not hasattr(args["geojson"], "__geo_interface__")  # for geopandas
#    1956         else args["geojson"].__geo_interface__
#    1957     )
#    1959 # Compute marginal attribute: copy to appropriate marginal_*
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/geoseries.py:240, in GeoSeries.__geo_interface__(self)
#     238 from geopandas import GeoDataFrame
# --> 240 return GeoDataFrame({"geometry": self}).__geo_interface__
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/geodataframe.py:537, in GeoDataFrame.__geo_interface__(self)
#     528 """Returns a ``GeoDataFrame`` as a python feature collection.
#     529
#     530 Implements the `geo_interface`. The returned python data structure
#    (...)
#     535 default args instead of a method
#     536 """
# --> 537 return self._to_geo(na="null", show_bbox=True)
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/geodataframe.py:617, in GeoDataFrame._to_geo(self, **kwargs)
#     610 """
#     611 Returns a python feature collection (i.e. the geointerface)
#     612 representation of the GeoDataFrame.
#     613
#     614 """
#     615 geo = {
#     616     "type": "FeatureCollection",
# --> 617     "features": list(self.iterfeatures(**kwargs)),
#     618 }
#     620 if kwargs.get("show_bbox", False):
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/geodataframe.py:603, in GeoDataFrame.iterfeatures(self, na, show_bbox)
#     598 for fid, geom in zip(ids, geometries):
#     599     feature = {
#     600         "id": str(fid),
#     601         "type": "Feature",
#     602         "properties": {},
# --> 603         "geometry": mapping(geom) if geom else None,
#     604     }
#     605     if show_bbox:
#
# File /opt/anaconda3/lib/python3.9/site-packages/shapely/geometry/geo.py:136, in mapping(ob)
#     117 """
#     118 Returns a GeoJSON-like mapping from a Geometry or any
#     119 object which implements __geo_interface__
#    (...)
#     134 {'type': 'Point', 'coordinates': (0.0, 0.0)}
#     135 """
# --> 136 return ob.__geo_interface__
#
# File /opt/anaconda3/lib/python3.9/site-packages/shapely/geometry/polygon.py:262, in Polygon.__geo_interface__(self)
#     260 @property
#     261 def __geo_interface__(self):
# --> 262     if self.exterior == LinearRing():
#     263         coords = []
#
# File /opt/anaconda3/lib/python3.9/site-packages/shapely/geometry/polygon.py:246, in Polygon.exterior(self)
#     244 @property
#     245 def exterior(self):
# --> 246     return shapely.get_exterior_ring(self)
#
# File /opt/anaconda3/lib/python3.9/site-packages/shapely/decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#
# File /opt/anaconda3/lib/python3.9/site-packages/shapely/_geometry.py:437, in get_exterior_ring(geometry, **kwargs)
#     416 """Returns the exterior ring of a polygon.
#     417
#     418 Parameters
#    (...)
#     435 True
#     436 """
# --> 437 return lib.get_exterior_ring(geometry, **kwargs)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
