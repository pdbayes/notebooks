# %% [markdown]
# # H3-Pandas Intro

# %%
# !pip uninstall pygeos --yes
# !pip install h3pandas --user
# Out:
# WARNING: Skipping pygeos as it is not installed.
# Requirement already satisfied: h3pandas in ./.local/lib/python3.9/site-packages (0.2.6)
# Requirement already satisfied: geopandas in /opt/anaconda3/lib/python3.9/site-packages (from h3pandas) (0.8.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (from h3pandas) (1.24.3)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from h3pandas) (2.1.4)
# Requirement already satisfied: shapely in /opt/anaconda3/lib/python3.9/site-packages (from h3pandas) (2.0.1)
# Requirement already satisfied: h3 in /opt/anaconda3/lib/python3.9/site-packages (from h3pandas) (3.6.4)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.9/site-packages (from h3pandas) (4.11.0)
# Requirement already satisfied: fiona in /opt/anaconda3/lib/python3.9/site-packages (from geopandas->h3pandas) (1.9.4.post1)
# Requirement already satisfied: pyproj>=2.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from geopandas->h3pandas) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->h3pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->h3pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->h3pandas) (2023.3)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from pyproj>=2.2.0->geopandas->h3pandas) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->h3pandas) (1.16.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->h3pandas) (23.1.0)
# Requirement already satisfied: click~=8.0 in /opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->h3pandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->h3pandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->h3pandas) (0.7.2)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->h3pandas) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata->fiona->geopandas->h3pandas) (3.17.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import h3pandas

# %% [markdown]
# ## Fetch data

# %% [markdown]
# We will use the NYC Taxi dataset for this demo

# %%
# Download and subset data
df = pd.read_csv('https://github.com/uber-web/kepler.gl-data/raw/master/nyctrips/data.csv')
df = df.rename({'pickup_longitude': 'lng', 'pickup_latitude': 'lat'}, axis=1)[['lng', 'lat', 'passenger_count']]

# %% [markdown]
# Only use the central part of the data

# %%
qt = 0.1
df = df.loc[(df['lng'] > df['lng'].quantile(qt)) & (df['lng'] < df['lng'].quantile(1-qt))& (df['lat'] > df['lat'].quantile(qt)) & (df['lat'] < df['lat'].quantile(1-qt))]

# %% [markdown]
# ## H3-Pandas

# %% [markdown]
# ### Basic H3 API

# %% [markdown]
# #### `geo_to_h3`

# %% [markdown]
# We can use `geo_to_h3` to add an index with H3 addresses resolution 10

# %% [markdown]
# `geo_to_h3` assumes coordinates are in `epsg=4326`

# %% [markdown]
# **NOTE**: `geo_to_h3` also works with `POINT` GeoDataFrames

# %%
dfh3 = df.h3.geo_to_h3(10)
dfh3.head()
# Out:
#                        lng        lat  passenger_count
# h3_10
# 8a2a100d2c87fff -73.993896  40.750111                1
# 8a2a100d2a07fff -73.976425  40.739811                1
# 8a2a100d630ffff -73.968704  40.754246                5
# 8a2a100d629ffff -73.976601  40.751896                1
# 8a2a100d2557fff -73.994957  40.745079                1

# %%
df.plot.scatter(x='lng', y='lat', figsize=(6,10), alpha=0.05)
# Out:
# <Axes: xlabel='lng', ylabel='lat'>

# %% [markdown]
# #### `h3_to_geo_boundary()`

# %% [markdown]
# We can see how many passengers fall into each H3 hexagon.

# %% [markdown]
# For now, we will pretend H3-Pandas does not have [aggregation functions](#Aggregation-functions) and perform the aggregations manually

# %%
dfh3 = dfh3.drop(columns=['lng', 'lat']).groupby('h3_10').sum()

# %% [markdown]
# We can now add a H3 hexagonal geometry to each row

# %%
gdfh3 = dfh3.h3.h3_to_geo_boundary()
gdfh3.head()
# Out:
#                  passenger_count  \
# h3_10
# 8a2a10089007fff               17
# 8a2a1008900ffff              110
# 8a2a10089017fff                9
# 8a2a1008901ffff               97
# 8a2a1008902ffff              117
#
#                                                           geometry
# h3_10
# 8a2a10089007fff  POLYGON ((-73.95877 40.78037, -73.95969 40.780...
# 8a2a1008900ffff  POLYGON ((-73.95843 40.77924, -73.95934 40.779...
# 8a2a10089017fff  POLYGON ((-73.96032 40.78070, -73.96123 40.780...
# 8a2a1008901ffff  POLYGON ((-73.95997 40.77958, -73.96088 40.779...
# 8a2a1008902ffff  POLYGON ((-73.95723 40.78003, -73.95814 40.779...

# %%
gdfh3.plot(column='passenger_count', figsize=(10, 10))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 gdfh3.plot(column='passenger_count', figsize=(10, 10))
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/geodataframe.py:921, in GeoDataFrame.plot(self, *args, **kwargs)
#     911 def plot(self, *args, **kwargs):
#     912     """Generate a plot of the geometries in the ``GeoDataFrame``.
#     913
#     914     If the ``column`` parameter is given, colors plot according to values
#    (...)
#     919     from there.
#     920     """
# --> 921     return plot_dataframe(self, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:722, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     720 subset = values[poly_idx & np.invert(nan_idx)]
#     721 if not polys.empty:
# --> 722     _plot_polygon_collection(
#     723         ax, polys, subset, vmin=mn, vmax=mx, cmap=cmap, **style_kwds
#     724     )
#     726 # plot all LineStrings and MultiLineString components in same collection
#     727 lines = expl_series[line_idx & np.invert(nan_idx)]
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:146, in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     142     kwargs["color"] = color
#     144 _expand_kwargs(kwargs, multiindex)
# --> 146 collection = PatchCollection([PolygonPatch(poly) for poly in geoms], **kwargs)
#     148 if values is not None:
#     149     collection.set_array(np.asarray(values))
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:146, in <listcomp>(.0)
#     142     kwargs["color"] = color
#     144 _expand_kwargs(kwargs, multiindex)
# --> 146 collection = PatchCollection([PolygonPatch(poly) for poly in geoms], **kwargs)
#     148 if values is not None:
#     149     collection.set_array(np.asarray(values))
#
# File /opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:87, in PolygonPatch(polygon, **kwargs)
#      73 def PolygonPatch(polygon, **kwargs):
#      74     """Constructs a matplotlib patch from a geometric object
#      75
#      76     The `polygon` may be a Shapely or GeoJSON-like object with or without holes.
#    (...)
#      85
#      86     """
# ---> 87     return PathPatch(PolygonPath(polygon), **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:62, in PolygonPath(polygon)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
# ---> 62 vertices = concatenate([
#      63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# File /opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:63, in <listcomp>(.0)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
#      62 vertices = concatenate([
# ---> 63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# IndexError: too many indices for array: array is 0-dimensional, but 2 were indexed

# %% [markdown]
# #### `h3_to_parent`

# %% [markdown]
# If we want to perform the analysis on a coarser resolution, we can use `h3_to_parent`

# %%
gdfh3_9 = gdfh3.h3.h3_to_parent(9)
gdfh3_9.head()
# Out:
#                  passenger_count  \
# h3_10
# 8a2a10089007fff               17
# 8a2a1008900ffff              110
# 8a2a10089017fff                9
# 8a2a1008901ffff               97
# 8a2a1008902ffff              117
#
#                                                           geometry  \
# h3_10
# 8a2a10089007fff  POLYGON ((-73.95877 40.78037, -73.95969 40.780...
# 8a2a1008900ffff  POLYGON ((-73.95843 40.77924, -73.95934 40.779...
# 8a2a10089017fff  POLYGON ((-73.96032 40.78070, -73.96123 40.780...
# 8a2a1008901ffff  POLYGON ((-73.95997 40.77958, -73.96088 40.779...
# 8a2a1008902ffff  POLYGON ((-73.95723 40.78003, -73.95814 40.779...
#
#                            h3_09
# h3_10
# 8a2a10089007fff  892a1008903ffff
# 8a2a1008900ffff  892a1008903ffff
# 8a2a10089017fff  892a1008903ffff
# 8a2a1008901ffff  892a1008903ffff
# 8a2a1008902ffff  892a1008903ffff

# %% [markdown]
# Again, we pretend that we cannot use [aggregation functions](#Aggregation-functions) and perform the operations manually.

# %%
gdfh3_9 = gdfh3_9.set_index('h3_09').groupby('h3_09').sum().h3.h3_to_geo_boundary()
gdfh3_9.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# File <__array_function__ internals>:200, in sum(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2324, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2322     return res
# -> 2324 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2325                       initial=initial, where=where)
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:84, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
# ---> 84             return reduction(axis=axis, out=out, **passkwargs)
#      86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:6204, in Series.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#    6195 @doc(make_doc("sum", ndim=1))
#    6196 def sum(
#    6197     self,
#    (...)
#    6202     **kwargs,
#    6203 ):
# -> 6204     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:12078, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12070 def sum(
#   12071     self,
#   12072     axis: Axis | None = 0,
#    (...)
#   12076     **kwargs,
#   12077 ):
# > 12078     return self._min_count_stat_function(
#   12079         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12080     )
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:12061, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12059     axis = 0
# > 12061 return self._reduce(
#   12062     func,
#   12063     name=name,
#   12064     axis=axis,
#   12065     skipna=skipna,
#   12066     numeric_only=numeric_only,
#   12067     min_count=min_count,
#   12068 )
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:6119, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6117 if isinstance(delegate, ExtensionArray):
#    6118     # dispatch to ExtensionArray interface
# -> 6119     return delegate._reduce(name, skipna=skipna, **kwds)
#    6121 else:
#    6122     # dispatch to numpy arrays
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/array.py:1002, in GeometryArray._reduce(self, name, skipna, **kwargs)
#    1001     return getattr(to_shapely(self), name)()
# -> 1002 raise TypeError(
#    1003     "cannot perform {name} with type {dtype}".format(
#    1004         name=name, dtype=self.dtype
#    1005     )
#    1006 )
#
# TypeError: cannot perform sum with type geometry
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 gdfh3_9 = gdfh3_9.set_index('h3_09').groupby('h3_09').sum().h3.h3_to_geo_boundary()
#       2 gdfh3_9.head()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:3063, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3058 else:
#    3059     # If we are grouping on categoricals we want unobserved categories to
#    3060     # return zero, rather than the default of NaN which the reindexing in
#    3061     # _agg_general() returns. GH #31422
#    3062     with com.temp_setattr(self, "observed", True):
# -> 3063         result = self._agg_general(
#    3064             numeric_only=numeric_only,
#    3065             min_count=min_count,
#    3066             alias="sum",
#    3067             npfunc=np.sum,
#    3068         )
#    3070     return self._reindex_output(result, fill_value=0)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1839, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1830 @final
#    1831 def _agg_general(
#    1832     self,
#    (...)
#    1837     npfunc: Callable,
#    1838 ):
# -> 1839     result = self._cython_agg_general(
#    1840         how=alias,
#    1841         alt=npfunc,
#    1842         numeric_only=numeric_only,
#    1843         min_count=min_count,
#    1844     )
#    1845     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:1431, in BlockManager.grouped_reduce(self, func)
#    1429             result_blocks = extend_blocks(applied, result_blocks)
#    1430     else:
# -> 1431         applied = blk.apply(func)
#    1432         result_blocks = extend_blocks(applied, result_blocks)
#    1434 if len(result_blocks) == 0:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1926, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1923 else:
#    1924     return result
# -> 1926 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927 return result
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1878, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1876     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1877     # preserve the kind of exception that raised
# -> 1878     raise type(err)(msg) from err
#    1880 if ser.dtype == object:
#    1881     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->sum,dtype->geometry]

# %%
gdfh3_9.plot(column='passenger_count', figsize=(10, 10))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 gdfh3_9.plot(column='passenger_count', figsize=(10, 10))
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/geodataframe.py:921, in GeoDataFrame.plot(self, *args, **kwargs)
#     911 def plot(self, *args, **kwargs):
#     912     """Generate a plot of the geometries in the ``GeoDataFrame``.
#     913
#     914     If the ``column`` parameter is given, colors plot according to values
#    (...)
#     919     from there.
#     920     """
# --> 921     return plot_dataframe(self, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:722, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     720 subset = values[poly_idx & np.invert(nan_idx)]
#     721 if not polys.empty:
# --> 722     _plot_polygon_collection(
#     723         ax, polys, subset, vmin=mn, vmax=mx, cmap=cmap, **style_kwds
#     724     )
#     726 # plot all LineStrings and MultiLineString components in same collection
#     727 lines = expl_series[line_idx & np.invert(nan_idx)]
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:146, in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     142     kwargs["color"] = color
#     144 _expand_kwargs(kwargs, multiindex)
# --> 146 collection = PatchCollection([PolygonPatch(poly) for poly in geoms], **kwargs)
#     148 if values is not None:
#     149     collection.set_array(np.asarray(values))
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:146, in <listcomp>(.0)
#     142     kwargs["color"] = color
#     144 _expand_kwargs(kwargs, multiindex)
# --> 146 collection = PatchCollection([PolygonPatch(poly) for poly in geoms], **kwargs)
#     148 if values is not None:
#     149     collection.set_array(np.asarray(values))
#
# File /opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:87, in PolygonPatch(polygon, **kwargs)
#      73 def PolygonPatch(polygon, **kwargs):
#      74     """Constructs a matplotlib patch from a geometric object
#      75
#      76     The `polygon` may be a Shapely or GeoJSON-like object with or without holes.
#    (...)
#      85
#      86     """
# ---> 87     return PathPatch(PolygonPath(polygon), **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:62, in PolygonPath(polygon)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
# ---> 62 vertices = concatenate([
#      63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# File /opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:63, in <listcomp>(.0)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
#      62 vertices = concatenate([
# ---> 63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# IndexError: too many indices for array: array is 0-dimensional, but 2 were indexed

# %% [markdown]
# ## H3-Pandas Extended API: The same workflow, streamlined

# %% [markdown]
# The entire above workflow can be performed in one line using aggregation functions of H3-Pandas, namely
# - `h3.geo_to_h3_aggregate`
# - `h3.h3_to_parent_aggregate`

# %%
gdfh3_9_alt = df.h3.geo_to_h3_aggregate(10, return_geometry=False).h3.h3_to_parent_aggregate(9)

# %%
gdfh3_9_alt.plot(column='passenger_count', figsize=(10, 10))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 gdfh3_9_alt.plot(column='passenger_count', figsize=(10, 10))
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/geodataframe.py:921, in GeoDataFrame.plot(self, *args, **kwargs)
#     911 def plot(self, *args, **kwargs):
#     912     """Generate a plot of the geometries in the ``GeoDataFrame``.
#     913
#     914     If the ``column`` parameter is given, colors plot according to values
#    (...)
#     919     from there.
#     920     """
# --> 921     return plot_dataframe(self, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:722, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     720 subset = values[poly_idx & np.invert(nan_idx)]
#     721 if not polys.empty:
# --> 722     _plot_polygon_collection(
#     723         ax, polys, subset, vmin=mn, vmax=mx, cmap=cmap, **style_kwds
#     724     )
#     726 # plot all LineStrings and MultiLineString components in same collection
#     727 lines = expl_series[line_idx & np.invert(nan_idx)]
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:146, in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     142     kwargs["color"] = color
#     144 _expand_kwargs(kwargs, multiindex)
# --> 146 collection = PatchCollection([PolygonPatch(poly) for poly in geoms], **kwargs)
#     148 if values is not None:
#     149     collection.set_array(np.asarray(values))
#
# File /opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:146, in <listcomp>(.0)
#     142     kwargs["color"] = color
#     144 _expand_kwargs(kwargs, multiindex)
# --> 146 collection = PatchCollection([PolygonPatch(poly) for poly in geoms], **kwargs)
#     148 if values is not None:
#     149     collection.set_array(np.asarray(values))
#
# File /opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:87, in PolygonPatch(polygon, **kwargs)
#      73 def PolygonPatch(polygon, **kwargs):
#      74     """Constructs a matplotlib patch from a geometric object
#      75
#      76     The `polygon` may be a Shapely or GeoJSON-like object with or without holes.
#    (...)
#      85
#      86     """
# ---> 87     return PathPatch(PolygonPath(polygon), **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:62, in PolygonPath(polygon)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
# ---> 62 vertices = concatenate([
#      63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# File /opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:63, in <listcomp>(.0)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
#      62 vertices = concatenate([
# ---> 63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# IndexError: too many indices for array: array is 0-dimensional, but 2 were indexed
